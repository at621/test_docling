# %% [markdown]
# ## Review docling implementation
#
# Also see: https://ds4sd.github.io/docling/concepts/docling_document/#basic-structure

# %%
from docling.document_converter import DocumentConverter
import json
import re

# %% [markdown]
# ### A. Convert document to json

# %%
# Transform pdf
source = "https://www.eba.europa.eu/sites/default/files/documents/10180/1597103/004d3356-a9dc-49d1-aab1-3591f4d42cbb/Final%20Report%20on%20Guidelines%20on%20default%20definition%20%28EBA-GL-2016-07%29.pdf"
converter = DocumentConverter()
result = converter.convert(source)

# Save the dictionary to a JSON file
with open('eba_dod.json', 'w', encoding='utf-8') as json_file:
    json.dump(result.document.export_to_dict(), json_file, indent=4)

# Write the result to a markdown file
with open('eba_dod.md', 'w', encoding='utf-8') as f:
    f.write(result.document.export_to_markdown())

print("Document saved as JSON and markdown file!")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Document saved as JSON and markdown file!

# %% [markdown]
# ### B. Inspect the contents

# %%
doc = result.document.export_to_dict()

# %%
def extract_headings(doc):
    result = []
    texts = doc.get('texts', [])

    for text in texts:
        label = text.get('label', '')
        level = text.get('level', None)
        
        if label == 'section_header' and level in [1, 2]:
            orig = text.get('orig', '')
            prov = text.get('prov', [])
            result.append((level, orig, prov[0]['page_no']))

    return result

# Extract headings
headings = extract_headings(doc)
for level, orig, page_no in headings:
    print(f"Level {level} | {page_no} | {orig} ")
# Out:
# Level 1 | 1 | Final Report
# Level 1 | 2 | Contents
# Level 1 | 3 | 1. Executive Summary
# Level 1 | 3 | Next steps
# Level 1 | 4 | 2. Background and rationale
# Level 1 | 4 | 2.1 Implementation of the changes in the definition of default
# Level 1 | 5 | 2.2 Past due criterion in the identification of default
# Level 1 | 5 | 2.2.1 Counting of days past due
# Level 1 | 5 | 2.2.2 Technical past due situation
# Level 1 | 6 | 2.2.3 Exposures to central governments, local authorities and public sector entities
# Level 1 | 7 | 2.2.4 Factoring and purchased receivables
# Level 1 | 7 | 2.2.5 Materiality threshold
# Level 1 | 7 | 2.3 Indications of unlikeliness to pay
# Level 1 | 7 | 2.3.1 Specific credit risk adjustments (SCRA)
# Level 1 | 9 | 2.3.2 Sale of credit obligations
# Level 1 | 9 | 2.3.3 Distressed restructuring
# Level 1 | 10 | 2.3.4 Bankruptcy
# Level 1 | 10 | 2.3.5 Additional indications of unlikeliness to pay
# Level 1 | 11 | 2.4 Application of the definition of default in external data
# Level 1 | 11 | 2.5 Criteria for a return to non-defaulted status
# Level 1 | 12 | 2.6 Consistency of the application of the definition of default
# Level 1 | 13 | 2.7 Application of the definition of default for retail exposures
# Level 1 | 13 | 2.7.1 Level of application of the definition of default
# Level 1 | 14 | 2.7.2 Pulling effect
# Level 1 | 14 | 2.7.3 Materiality threshold for joint exposures
# Level 1 | 15 | 2.8 Documentation, internal policies and risk management processes
# Level 1 | 15 | 2.8.1 Documentation
# Level 1 | 15 | 2.8.2 Internal governance
# Level 1 | 16 | 3. Draft guidelines
# Level 1 | 17 | Guidelines
# Level 1 | 18 | 1. Compliance and reporting obligations
# Level 1 | 18 | Status of these guidelines
# Level 1 | 18 | Reporting requirements
# Level 1 | 19 | 2. Subject matter, scope and definitions
# Level 1 | 19 | Subject matter
# Level 1 | 19 | Scope of application
# Level 1 | 19 | Addressees
# Level 1 | 19 | Definitions
# Level 1 | 20 | 3. Implementation
# Level 1 | 20 | Date of application
# Level 1 | 20 | First application of the Guidelines by IRB institutions
# Level 1 | 21 | Repeal
# Level 1 | 21 | 4. Past due criterion in the identification of default
# Level 1 | 21 | Counting of days past due
# Level 1 | 23 | Technical past due situation
# Level 1 | 23 | Exposures to central governments, local authorities and public sector entities
# Level 1 | 24 | Specific provisions applicable to factoring and purchased receivables
# Level 1 | 25 | Setting the materiality threshold
# Level 1 | 26 | 5. Indications of unlikeliness to pay
# Level 1 | 26 | Non-accrued status
# Level 1 | 26 | Specific credit risk adjustments (SCRA)
# Level 1 | 27 | Sale of the credit obligation
# Level 1 | 29 | Distressed restructuring
# Level 1 | 30 | Bankruptcy
# Level 1 | 31 | Other indications of unlikeliness to pay
# Level 1 | 33 | Governance processes regarding unlikeliness to pay
# Level 1 | 33 | 6. Application of the definition of default in external data
# Level 1 | 34 | 7. Criteria for the return to a nondefaulted status
# Level 1 | 34 | Minimum conditions for reclassification to a non-defaulted status
# Level 1 | 36 | Monitoring of the effectiveness of the policy
# Level 1 | 37 | 8. Consistency in the application of the definition of default
# Level 1 | 37 | Overview
# Level 1 | 37 | Consistent identification of default of a single obligor
# Level 1 | 38 | Consistent use of the definition of default across types of exposures
# Level 1 | 39 | 9. Application of the definition of default for retail exposures
# Level 1 | 39 | Level of application of the default definition for retail exposures
# Level 1 | 40 | Application of the definition of default for retail exposures at the facility level
# Level 1 | 41 | Application of the definition of default for retail exposures at the obligor level
# Level 1 | 43 | 10. Documentation, internal policies and risk management processes
# Level 1 | 43 | Timeliness of the identification of default
# Level 1 | 44 | Documentation
# Level 1 | 45 | Internal governance requirements for institutions applying the IRB Approach
# Level 1 | 46 | 4. Accompanying documents
# Level 1 | 46 | 4.1 Impact assessment
# Level 1 | 46 | A. Problem identification
# Level 1 | 46 | B. Policy objectives
# Level 1 | 47 | C. Baseline scenario
# Level 1 | 49 | D. Options considered
# Level 1 | 49 | Treatment of retail exposures
# Level 1 | 50 | Treatment of the pulling effect
# Level 1 | 51 | Definition of technical past due situations
# Level 1 | 53 | Exposures to central governments, local authorities and public sector entities
# Level 1 | 54 | Alignment with the supervisory reporting framework
# Level 1 | 55 | Treatment of provisions under IFRS 9
# Level 1 | 56 | Threshold for the sale of credit obligations
# Level 1 | 58 | Threshold for distressed restructuring
# Level 1 | 58 | Probation period for a return to non-defaulted status
# Level 1 | 60 | Probation period and other conditions for distressed restructuring
# Level 1 | 60 | Frequency of counting of days past due
# Level 1 | 62 | E. Impacts of the technical options
# Level 1 | 64 | QIS results: technical past due situations
# Level 1 | 64 | QIS results: specific credit risk adjustments (SCRA)
# Level 1 | 65 | QIS results: sale of credit obligations
# Level 1 | 65 | QIS results: probation period before a return to non-defaulted status
# Level 1 | 66 | QIS results: probation period for exposures subject to distressed restructuring
# Level 1 | 66 | QIS results: contagion effect
# Level 1 | 67 | F. Cost-benefit analysis
# Level 1 | 67 | Costs for institutions
# Level 1 | 68 | Costs for national supervisory authorities
# Level 1 | 68 | Benefits
# Level 1 | 69 | 4.2 Views of the Banking Stakeholder Group (BSG)
# Level 1 | 69 | General comments
# Level 1 | 69 | Specific issues
# Level 1 | 71 | 4.3 Feedback on the public consultation and on the opinion of the BSG
# Level 1 | 71 | Summary of key issues and the EBA's response
# Level 1 | 73 | Summary of responses to the consultation and the EBA's analysis
# Level 1 | 74 | Summary of responses received
# Level 1 | 74 | EBA analysis
# Level 1 | 76 | Comments
# Level 1 | 76 | Summary of responses received
# Level 1 | 76 | EBA analysis
# Level 1 | 76 | Flexibility
# Level 1 | 76 | Payment allocation
# Level 1 | 76 | Amendments to the proposals
# Level 1 | 77 | Summary of responses received
# Level 1 | 77 | EBA analysis
# Level 1 | 77 | Materiality threshold
# Level 1 | 79 | EBA analysis
# Level 1 | 80 | Comments
# Level 1 | 80 | Summary of responses received
# Level 1 | 80 | EBA analysis
# Level 1 | 80 | Responses to questions in Consultation Paper EBA/CP/2015/15
# Level 1 | 80 | Expert judgement
# Level 1 | 81 | Comments
# Level 1 | 81 | Summary of responses received
# Level 1 | 81 | EBA analysis
# Level 1 | 82 | Amendments to the proposals
# Level 1 | 83 | Summary of responses received
# Level 1 | 83 | EBA analysis
# Level 1 | 83 | of days past due for these obligors.
# Level 1 | 89 | Comments
# Level 1 | 89 | Summary of responses received
# Level 1 | 89 | EBA analysis
# Level 1 | 89 | Expert judgement
# Level 1 | 89 | Dilution risk
# Level 1 | 89 | Reference date for DPD
# Level 1 | 89 | Amendments to the proposals
# Level 1 | 91 | Summary of responses received
# Level 1 | 91 | EBA analysis
# Level 1 | 96 | Summary of responses received
# Level 1 | 96 | EBA analysis
# Level 1 | 96 | Amendments to the proposals
# Level 1 | 99 | Summary of responses received
# Level 1 | 99 | EBA analysis
# Level 1 | 99 | Amendments to the proposals
# Level 1 | 100 | Summary of responses received
# Level 1 | 100 | EBA analysis
# Level 1 | 100 | Amendments to the proposals
# Level 1 | 100 | Q6. Do you agree that the purchase or origination of a financial asset at a material discount should be treated as an indication of unlikeliness to pay?
# Level 1 | 106 | Summary of responses received
# Level 1 | 106 | EBA analysis
# Level 1 | 106 | Amendments to the proposals
# Level 1 | 107 | Summary of responses received
# Level 1 | 107 | EBA analysis
# Level 1 | 107 | Question 11. Do you agree with the requirements on internal governance for banks that use the IRB Approach?
# Level 1 | 107 | Amendments to the proposals

# %%
def extract_paragraphs(doc):
    headings = []
    texts = doc.get('texts', [])

    for text in texts:
        label = text.get('label', '')
        
        if label == 'list_item':
            orig = text.get('orig', '')
            prov = text.get('prov', [])
            headings.append((orig, prov[0]['page_no']))

    return headings

# Extrtacts paragraphs
headings = extract_paragraphs(doc)
start_page = 0
for orig, page_no in headings:
    match = re.match(r'^(\d+)\.\s*(.*)', orig)
    if match:
        print(f"{page_no} | {match.group(1)} | {orig[:20]} ")
        start_page += 1
        assert start_page == int(match.group(1)), "Inconsistent numbering"
# Out:
# 18 | 1 | 1. This document con
# 18 | 2 | 2. Guidelines set th
# 18 | 3 | 3. According to Arti
# 18 | 4 | 4. Notifications wil
# 19 | 5 | 5. These guidelines
# 19 | 6 | 6. These guidelines
# 19 | 7 | 7. Institutions that
# 19 | 8 | 8. These guidelines
# 19 | 9 | 9. Unless otherwise
# 20 | 10 | 10. These guidelines
# 20 | 11 | 11. In order to appl
# 20 | 12 | 12. The changes refe
# 20 | 13 | 13. Institutions tha
# 21 | 14 | 14. After IRB instit
# 21 | 15 | 15. Sections 3.3.2.1
# 21 | 16 | 16. For the purposes
# 21 | 17 | 17. Where the credit
# 21 | 18 | 18. Where the repaym
# 22 | 19 | 19. Where the repaym
# 22 | 20 | 20. Where the obligo
# 22 | 21 | 21. The calculation
# 22 | 22 | 22. The classificati
# 23 | 23 | 23. A technical past
# 23 | 24 | 24. Technical past d
# 23 | 25 | 25. Institutions may
# 24 | 26 | 26. Institutions tha
# 24 | 27 | 27. Where there are
# 24 | 28 | 28. Where there are
# 25 | 29 | 29. Where the instit
# 25 | 30 | 30. Events recognise
# 25 | 31 | 31. Where the obligo
# 25 | 32 | 32. In the specific
# 25 | 33 | 33. Competent author
# 26 | 34 | 34. Institutions sho
# 26 | 35 | 35. For the purposes
# 26 | 36 | 36. For the purposes
# 26 | 37 | 37. The SCRA that co
# 26 | 38 | 38. Where the instit
# 27 | 39 | 39. Where the instit
# 27 | 40 | 40. Where the instit
# 27 | 41 | 41. For the purposes
# 27 | 42 | 42. Institutions sho
# 28 | 43 | 43. Where, however,
# 28 | 44 | 44. Institutions sho
# 28 | 45 | 45. In order to asse
# 28 | 46 | 46. The sale of cred
# 28 | 47 | 47. If the sale of a
# 28 | 48 | 48. In the case of a
# 29 | 49 | 49. For the purposes
# 29 | 50 | 50. Given that, as r
# 29 | 51 | 51. Institutions sho
# 29 | 52 | 52. For the purposes
# 30 | 53 | 53. If however the d
# 30 | 54 | 54. Any concession e
# 30 | 55 | 55. Where any of the
# 30 | 56 | 56. For the purposes
# 31 | 57 | 57. Institutions sho
# 31 | 58 | 58. Institutions sho
# 31 | 59 | 59. The possible ind
# 32 | 60 | 60. Institutions sho
# 32 | 61 | 61. When specifying
# 32 | 62 | 62. Where a financia
# 33 | 63 | 63. Institutions sho
# 33 | 64 | 64. Institutions sho
# 33 | 65 | 65. With regard to e
# 33 | 66 | 66. Institutions tha
# 33 | 67 | 67. For the purposes
# 34 | 68 | 68. For each differe
# 34 | 69 | 69. Regarding the to
# 34 | 70 | 70. Where the assess
# 34 | 71 | 71. For the purposes
# 35 | 72 | 72. For the purposes
# 35 | 73 | 73. Institutions sho
# 36 | 74 | 74. Where the obligo
# 36 | 75 | 75. For the purposes
# 36 | 76 | 76. Institutions sho
# 37 | 77 | 77. It is expected t
# 37 | 78 | 78. The analysis of
# 37 | 79 | 79. Institutions sho
# 37 | 80 | 80. For the purposes
# 37 | 81 | 81. Where the exchan
# 38 | 82 | 82. Further, where t
# 38 | 83 | 83. For the purposes
# 38 | 84 | 84. For the purposes
# 39 | 85 | 85. Further, for ins
# 39 | 86 | 86. According to the
# 39 | 87 | 87. Institutions sho
# 39 | 88 | 88. Institutions may
# 39 | 89 | 89. Where institutio
# 39 | 90 | 90. Where institutio
# 40 | 91 | 91. The same rule sh
# 40 | 92 | 92. Where, in accord
# 40 | 93 | 93. Institutions sho
# 40 | 94 | 94. Additionally, wh
# 41 | 95 | 95. The application
# 41 | 96 | 96. Institutions sho
# 41 | 97 | 97. Where the condit
# 41 | 98 | 98. The default of a
# 41 | 99 | 99. Where the condit
# 42 | 100 | 100. Institutions sh
# 42 | 101 | 101. Institutions sh
# 42 | 102 | 102. Additionally, i
# 42 | 103 | 103. Where the defin
# 42 | 104 | 104. A joint obligor
# 43 | 105 | 105. When delay in p
# 43 | 106 | 106. Institutions sh
# 43 | 107 | 107. Institutions sh
# 43 | 108 | 108. Control mechani
# 44 | 109 | 109. Institutions sh
# 44 | 110 | 110. For the purpose
# 44 | 111 | 111. For the purpose
# 44 | 112 | 112. For the purpose
# 44 | 113 | 113. For the purpose
# 45 | 114 | 114. Institutions th
